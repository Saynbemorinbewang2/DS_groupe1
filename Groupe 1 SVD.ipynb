# %% [markdown]
# # Decomposition en Valeur Singulière (SVD)

# %% [markdown]
# ### L'algorithme SVD (Décomposition en Valeurs Singulières) est une méthode d'analyse de données qui permet de réduire la  dimensionnalité des données tout en préservant autant d'informations que possible

# %% [markdown]
# # 1.	Cas d’application de la SVD dans la société
#
#
# ##### La SVD peut être utilisée à diverses fins, telles que la réduction de dimensionnalité, la compression de données, la reconstruction de matrices, le traitement du signal, etc. Elle est largement utilisée dans les domaines de l'analyse des données, de l'apprentissage automatique et de la vision par ordinateur. Nous citons quelques exemples de cas d'utilisation

# %% [raw]
# a. Compression d’images : La SVD est utilisée pour compresser des images tout en préservant les informations essentielles.
# b.	Traitement du signal et de l’image : Elle permet d’analyser et de filtrer des signaux, ainsi que d’extraire des caractéristiques d’images.
# c.	Recommandation de produits : Dans le commerce électronique, la SVD recommande des produits aux utilisateurs en fonction de leurs préférences passées.
# d.	Analyse de texte : Réduit la dimensionnalité des matrices de termes-document pour faciliter la recherche d’informations pertinentes.

# %% [markdown]
# # 2.	Avantages de la SVD
#
#
# ##### Notons quelques avantages de la SVD:

# %% [raw]
# 1. Réduction de dimension : L'algorithme SVD permet de réduire la dimension d'une matrice en identifiant les valeurs singulières les plus importantes. Cela peut être utile pour compresser des données, éliminer le bruit ou extraire des caractéristiques significatives.
#
# 2. Interprétabilité : La décomposition SVD permet de représenter une matrice en termes de valeurs singulières et de vecteurs singuliers, ce qui peut faciliter l'interprétation des données et la compréhension des relations entre les variables.
#
# 3. Robustesse : L'algorithme SVD est relativement robuste aux données manquantes ou bruitées. Il peut effectuer des calculs même lorsque certaines valeurs de la matrice sont inconnues ou erronées.
#
# 4. Stabilité numérique : L'algorithme SVD est numériquement stable et précis. Il est peu sensible aux erreurs d'arrondi et offre des solutions cohérentes pour les problèmes de décomposition.

# %% [markdown]
# # 3.	Inconvénients de la SVD :

# %% [raw]
# La décomposition en valeurs singulières (SVD) est un outil puissant, mais elle présente également certains inconvénients :

# %% [raw]
# 1. Complexité computationnelle : Calculer la décomposition SVD complète d'une matrice peut être coûteux en termes de temps de calcul, en particulier pour les matrices de grande taille. Cela peut limiter son utilisation dans des cas où l'efficacité est primordiale.
#
# 2. Stockage requis : La décomposition SVD complète nécessite de stocker les matrices de valeurs singulières et de vecteurs singuliers, ce qui peut occuper beaucoup de mémoire, surtout pour les matrices de grande taille.
#
# 3. Sensibilité aux données aberrantes : L'algorithme SVD peut être affecté par des valeurs aberrantes dans les données, car il prend en compte tous les points de données lors du calcul des valeurs singulières. Cela peut influencer les résultats de manière non souhaitée.
#
# 4. Interprétabilité limitée : Bien que la décomposition SVD facilite l'interprétation des données, les vecteurs et les valeurs singulières ne sont pas toujours directement interprétables, surtout lorsque les matrices sont de grande dimension. L'algorithme de décomposition en valeurs singulières (SVD, Singular Value Decomposition en anglais) est une méthode utilisée en algèbre linéaire pour décomposer une matrice en trois composantes :

# %% [markdown]
# # 4 Concepts mathématiques et explications

# %% [markdown]
# #### Sois A une matrice de dimensions m × n. Voici comment nous pouvons effectuer la SVD :
# ##### 1.	Calcul des valeurs singulières (σ) :
# #### Trouvons les valeurs singulières de A en calculant la racine carrée des valeurs propres de la matrice A^T A (ou AA^T). Ces valeurs singulières sont triées par ordre décroissant.
# ####	Soit σ_1, σ_2, …, σ_r les valeurs singulières non nulles (où r est le rang de A).
# #### 2.	Matrices U et V :
# ####	Calculons la matrice U :
# ####	U est une matrice m × m dont les colonnes sont les vecteurs propres normalisés de AA^T (ou A^T A).
# ####	Les vecteurs propres correspondant aux valeurs singulières non nulles forment les colonnes de U.
# ####	Calculons la matrice V :
# ####	V est une matrice n × n dont les colonnes sont les vecteurs propres normalisés de A^T A (ou AA^T).
# ####	Les vecteurs propres correspondant aux valeurs singulières non nulles forment les colonnes de V.
# #### 3.Matrice Σ :
# ####	Construisons la matrice diagonale Σ :
# ####	Σ est une matrice m × n avec les valeurs singulières non nulles σ_1, σ_2, …, σ_r sur la diagonale.
# ####	Les autres éléments de Σ sont nuls.
# ####	Reconstruction de A :
# ####	La matrice A peut être reconstruite à partir de U, Σ et V^T :
# ####	A = UΣV^T

# %% [markdown]
# ## Importation des librairies

# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Appel du dataset et affichage de l'entete

# %%
df=pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # Exploration des donnees

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ## Description statistique du dataset

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ### visualisation de la corrélation

# %%
corr=df.corr()
corr
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
X=df.drop(columns=['Outcome'])
y = df["Outcome"]

# %%
X_svd = svd.fit_transform(X)
print(pd.DataFrame(X_svd, columns=[f"Component_{i+1}" for i in range(5)]))
# Out:
#      Component_1  Component_2  Component_3  Component_4  Component_5
# 0     133.432713  -116.926361     5.379143    14.941440    13.854766
# 1      87.481186   -76.930138   -19.662201     9.624827     4.484009
# 2     143.882747  -127.321902    44.950521    -6.466025   -12.281264
# 3     150.119410    -7.163655   -15.745145     2.081779    -5.637538
# 4     225.655340    26.685839    22.004533    20.302213    10.676701
# ..           ...          ...          ...          ...          ...
# 763   228.380467    38.496084   -30.068432     4.765658    34.919930
# 764   112.491380   -98.603542    -3.163442    13.541400    -4.777311
# 765   185.085271   -14.077029    -3.512253    -0.902245    -3.113351
# 766   110.593084   -99.137741    14.628976   -13.678762     9.748551
# 767    93.336795   -81.706381   -18.876376    14.046830    -4.354127
#
# [768 rows x 5 columns]

# %%
correlation_svd = pd.DataFrame(X_svd).corr()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Matrice de corrélation avant la SVD")
plt.show()

plt.figure(figsize=(10, 6))
sns.heatmap(correlation_svd, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Matrice de corrélation après la SVD")
plt.show()

# %%
sns.pairplot(pd.DataFrame(X))
plt.suptitle('Matrice de Nuages de Points', y=1.02)
plt.show()

# %%
sns.pairplot(pd.DataFrame(X_svd))
plt.suptitle('Matrice de Nuages de Points', y=1.02)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
tree_classifier = DecisionTreeClassifier()

# %%
tree_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_tree = tree_classifier.predict(X_test)

# %%
accuracy_tree = accuracy_score(y_test, y_pred_tree)
print(f"Exactitude de l'arbre de décision : {accuracy_tree:.2f}")
# Out:
# Exactitude de l'arbre de décision : 0.66

# %% [markdown]
# ### Application de SVD

# %%
X_train_svd = svd.fit_transform(X_train)
X_test_svd = svd.transform(X_test)

# %%
tree_classifier_svd = DecisionTreeClassifier()

# %%
tree_classifier_svd.fit(X_train_svd, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_tree_svd = tree_classifier_svd.predict(X_test_svd)

# %%
accuracy_tree_svd = accuracy_score(y_test, y_pred_tree_svd)
print(f"Exactitude avec SVD : {accuracy_tree_svd:.2f}")
# Out:
# Exactitude avec SVD : 0.68
